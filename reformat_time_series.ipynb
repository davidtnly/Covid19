# %%
import csv
import pandas as pd
from pandas import read_excel
import openpyxl

# %%
# data = read_excel("time_series_covid19_confirmed_US.xlsx")
data = pd.read_csv("time_series_covid19_confirmed_US.csv")

# %%
data_cols = ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2',
             'Province_State','Country_Region', 'Lat', 'Long_', 'Combined_Key']

date_cols = data[data.columns[~data.columns.isin(data_cols)]].columns

# %%
data.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 11/26/2020  11/27/2020  11/28/2020  11/29/2020  \
# 0  32.539527 -86.644082  ...       2704        2716        2735        2751
# 1  30.727750 -87.722071  ...       8576        8603        8733        8820
# 2  31.868263 -85.387129  ...       1170        1171        1173        1175
# 3  32.996421 -87.125115  ...       1170        1173        1179        1188
# 4  33.982109 -86.567906  ...       2879        2888        2922        2946
#
# ...

# %%
indexed_data = data.set_index(data_cols)

# %%
stacked_data = indexed_data.stack()

# %%
stacked_df = pd.DataFrame(stacked_data)

# %%
stacked_df
# Out:
#                                                                                                                                0
# UID      iso2 iso3 code3 FIPS    Admin2  Province_State Country_Region Lat       Long_       Combined_Key
# 84001001 US   USA  840   1001.0  Autauga Alabama        US             32.539527 -86.644082  Autauga, Alabama, US 4/1/2020    10
#                                                                                                                   4/2/2020    12
#                                                                                                                   4/3/2020    12
#                                                                                                                   4/4/2020    12
#                                                                                                                   4/5/2020    12
# ...

# %%
stacked_df.rename(columns = {'0':'new_name'})

# %%
stacked_df.to_csv("time_series.csv")

# %%
stacked_df.to_excel("time_series.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-6a2d9bb80ffd> in <module>
# ----> 1 stacked_df.to_excel("time_series.xlsx")
#
# ~\Anaconda3\envs\nlp\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2179             startcol=startcol,
#    2180             freeze_panes=freeze_panes,
# -> 2181             engine=engine,
#    2182         )
#    2183
#
# ~\Anaconda3\envs\nlp\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     733             startrow=startrow,
#     734             startcol=startcol,
# --> 735             freeze_panes=freeze_panes,
#     736         )
#     737         if need_save:
#
# ...
